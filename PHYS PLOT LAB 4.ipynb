# %%
import math
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)

loading=np.loadtxt(r'C:\Users\Admin\Downloads\Experiment1LAB4.csv', delimiter = ',')
x = loading[0]
y = loading[1]
phase = loading[2]

plt.title('Phase vs. Frequency for Experiment 1', fontsize=22)
plt.xlabel('Frequency (Hz)', fontsize=22)
plt.ylabel('Phase (radians)', fontsize=22)
x2 = np.linspace(1000,12000)
y2 = []
for a in range(50):
    y2.append(5.5/((2)**0.5))
plt.plot(x,phase,'o')
plt.savefig("gf2.png")

# %%
print(x[86])
print(x[78])
print(x[71])

print(phase[78])
# Out:
# 10555.555555555557
# 9666.666666666666
# 8888.888888888889
# -1.4229426184871268

# %%
loading2=np.loadtxt(r'C:\Users\Admin\Downloads\Experiment2NoSpoiler.csv', delimiter = ',')
xtwo = loading2[0]
ytwo = loading2[1]
phase = loading2[2]

plt.figure(figsize=(20,10))
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)

plt.title('Gain vs. Frequency for Experiment 2 without Spoiler', fontsize=22)
plt.xlabel('Frequency (Hz)', fontsize=22)
plt.ylabel('Gain', fontsize=22)
x2 = np.linspace(7000,13000)
y2 = []
for a in range(50):
    y2.append(max(ytwo)/((2)**0.5))
plt.plot(xtwo,ytwo,'o')
plt.plot(x2,y2,'--')
plt.savefig("gf3")

# %%
ind = np.argmax(loading2)
print(ind)
# Out:
# 99

# %%
print(xtwo[55]-xtwo[50])
print((xtwo[52]+xtwo[53])/2)
# Out:
# 303.0303030303039
# 10181.818181818182

# %%
loading3=np.loadtxt(r'C:\Users\Admin\Downloads\experiment2Spoiler.csv', delimiter = ',')
xthree = loading3[0]
ythree = loading3[1]
phase = loading3[2]

plt.figure(figsize=(20,10))
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)

plt.title('Gain vs. Frequency for Experiment 2 with Spoiler', fontsize=22)
plt.xlabel('Frequency (Hz)', fontsize=22)
plt.ylabel('Gain', fontsize=22)
x2 = np.linspace(7000,13000)
y2 = []
for a in range(50):
    y2.append(max(ythree)/((2)**0.5))
plt.plot(xthree,ythree,'o')
plt.plot(x2,y2,'--')
plt.savefig("gf4")

# %%
print(xthree[46])
print(ythree[46])
print(xthree[61])
print(ythree[61])
# Out:
# 9787.878787878788
# 0.020714285714285716
# 10696.969696969696
# 0.02

# %%
print(xthree[53])
# Out:
# 10212.121212121212
